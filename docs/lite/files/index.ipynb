# %% [markdown]
# # Machine Vision Toolbox for Python
#
# <table style="border-collapse: collapse; border: none;">
#   <tr>
#     <td style="border: none; padding: 0 12px 0 0;"><img src="https://github.com/petercorke/machinevision-toolbox-python/raw/main/docs/figs/VisionToolboxLogo_NoBackgnd@2x.png" width="200"></td>
#     <td style="border: none;"><div align="left"><font size="6">Interactive Browser Tutorials & Demos</font></div></td>
#   </tr>
# </table>
#
#
# Welcome to the interactive companion for the **Machine Vision Toolbox for Python**. These notebooks run entirely in your browser via **JupyterLite**—no installation, no configuration, just code.
#
# ---
#
# ## 🚀 Quick Start
# | Tutorial | Description |
# | :--- | :--- |
# | [**Introduction**](./intro.ipynb) | A quick introduction to the toolbox. |
#
# ---
#
# ## 🖼️ Image Fundamentals
# | Tutorial | Description |
# | :--- | :--- |
# | [**Exploring Images**](./exploring-images.ipynb) | The basics of images, pixels, and bit-depth. |
# | [**Grey scale images**](./greyscale-images.ipynb) | The basics of grey scale images. |
# | [**Color images**](./color-images.ipynb) | The basics of color images. |
# | [**Image Processing**](./image-processing.ipynb) | Fundamentals of filtering, kernels, and spatial operations. |
# | [**Understanding gamma**](./gamma.ipynb) | The most misunderstood image transform in CV. |
#
# ---
#
# ## 📷 Camera Geometry & Projection
# | Tutorial | Description |
# | :--- | :--- |
# | [**Camera Animation**](./camera_animation.ipynb) | **Interactive:** Visualize point projection on a central sensor. |
# | [**The Central Camera**](./camera.ipynb) | Introduction to the `CentralCamera` object and properties. |
# | [**Homogeneous Coords**](./homogeneous-coords.ipynb) | Math refresher on spatial transforms with interactive demo. |
# | [**Homography**](./homographies.ipynb) | Planar projections, warping, and estimation. |
# | [**Camera calibration**](./calibration.ipynb) | Calibrating a camera from a set of images. |
#
# ---
#
# ## 🔍 Advanced Vision Features
# | Tutorial | Description |
# | :--- | :--- |
# | [**Finding Blobs**](./finding-blobs.ipynb) | Region segmentation and shape analysis. |
# | [**Image convolution**](./image-convolution.ipynb) | Basis of smoothing, edge detection, and point features. |
# | [**Image Features**](./image-features.ipynb) | Point/corner detection (SIFT, ORB, etc.). |
# | [**Fiducial Markers**](./fiducials.ipynb) | Detecting ArUco markers and QR-like codes. |
# | [**Image Motion**](./image-motion.ipynb) | Relationship between camera motion (3D) and image (2D). |
# | [**Visual Servoing**](./IBVS.ipynb) | Image-Based Visual Servoing (IBVS). |
#
# ---
# <p align="center">
#   <img src="https://github.com/petercorke/machinevision-toolbox-python/raw/main/docs/figs/VisionToolboxLogo_NoBackgnd@2x.png" width="200">
#   <br>
#   <font size="2">Created by Peter Corke | QUT Centre for Robotics</font>
# </p>
